# %%
# This script processes vector data by compiling individual shapefiles into a single shapefile
# the files that are being created are:
##### 1) defoliated portion of fire perimeter (fire-year defoliated)
##### 2) non-defoliated portion of fire perimeter (fire-year non-defoliated)

# %%
# import libraries
import geopandas
import os, glob
import pandas
from pathlib import Path

# %%
# 1) fire-year defoliated
# read in files and concatenate all files

folder = Path("/Users/jgoldman/Library/CloudStorage/OneDrive-UniversityofToronto/Data/fire-only-sbw-only-perimeters/fire-year-defoliated")
outfolder = Path("/Users/jgoldman/Library/CloudStorage/OneDrive-UniversityofToronto/Data/fire-only-sbw-only-perimeters/cleaned")
shapefiles = folder.glob("*.shp")
gdf = pandas.concat([
   geopandas.read_file(str(shp)) # read in all files with the structure .shp
   for shp in shapefiles  # loop - for all shp in shapefiles (folder) pipe to dataframe
]).pipe(geopandas.GeoDataFrame)
gdf.to_file(outfolder / 'compiled.shp') # send it out
# Out:
# /var/folders/ct/ddw0sd294ls6ktmlw9l8bwgm0000gn/T/ipykernel_84459/3598238769.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gdf = pandas.concat([

# %%
# 1) fire-year defoliated
# compiled file
defolFire = geopandas.read_file(outfolder/ 'compiled.shp')

defolFire.head()
# Out:
#   FID_ON_Fir    OGF_ID                     r_id           raster_id  \
# 0        115  46001767  THU58_1996_127_rbr_.tif  THU58_1996_127_rbr
# 1        121  46001675  FOR11_1996_134_rbr_.tif  FOR11_1996_134_rbr
# 2        129  46001778  THU84_1996_147_rbr_.tif  THU84_1996_147_rbr
# 3        183  46001696  NIP60_1996_227_rbr_.tif  NIP60_1996_227_rbr
# 4        189  46001686  NIP39_1996_236_rbr_.tif  NIP39_1996_236_rbr
#
#           Fire_ID FIRE_DISTU FIRE_TYPE_ Fire_Year FIRE_GENER FIRE_RESPO  ...  \
# 0  THU58_1996_127      THU58        IFR      1996        LTG        SUP  ...
# 1  FOR11_1996_134      FOR11        IFR      1996        LTG        SUP  ...
# 2  THU84_1996_147      THU84        IFR      1996        LTG        SUP  ...
# 3  NIP60_1996_227      NIP60        IFR      1996        LTG        SUP  ...
# 4  NIP39_1996_236      NIP39        IFR      1996        LTG        SUP  ...
#
#   OBJECTID SHAPEAREA SHAPELEN old_f_id  RBR   TIF FID_Dissol Shape_Leng  \
# ...

# %%
#1) fire-year defoliated
# check str
defolFire.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 321 entries, 0 to 320
# Data columns (total 29 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   FID_ON_Fir  321 non-null    object
#  1   OGF_ID      321 non-null    object
#  2   r_id        321 non-null    object
#  3   raster_id   321 non-null    object
#  4   Fire_ID     321 non-null    object
#  5   FIRE_DISTU  321 non-null    object
#  6   FIRE_TYPE_  321 non-null    object
#  7   Fire_Year   321 non-null    object
#  8   FIRE_GENER  321 non-null    object
#  9   FIRE_RESPO  321 non-null    object
#  10  FIRE_START  321 non-null    object
#  11  FIRE_OUT_D  321 non-null    object
#  12  FIRE_FINAL  321 non-null    object
#  13  LOCATION_A  321 non-null    object
#  14  BUSINESS_E  318 non-null    object
#  15  GENERAL_CO  198 non-null    object
#  16  GEOMETRY_U  12 non-null     object
#  17  EFFECTIVE_  321 non-null    object
#  18  SYSTEM_DAT  321 non-null    object
# ...

# %%
# 2) fire-year non-defoliated
# read in files and concatenate all files

folder = Path("/Users/jgoldman/Library/CloudStorage/OneDrive-UniversityofToronto/Data/fire-only-sbw-only-perimeters/fire-year-non-defoliated")
outfolder = Path("/Users/jgoldman/Library/CloudStorage/OneDrive-UniversityofToronto/Data/fire-only-sbw-only-perimeters/cleaned")
shapefiles = folder.glob("*.shp")
gdf = pandas.concat([
   geopandas.read_file(str(shp)) # read in all files with the structure .shp
   for shp in shapefiles  # loop - for all shp in shapefiles (folder) pipe to dataframe
]).pipe(geopandas.GeoDataFrame)
gdf.to_file(outfolder / 'non-defoliated-compiled.shp') # send it out

# %%
# 2) fire-year non-defoliated
# compiled file
NdefolFire = geopandas.read_file(outfolder/ 'non-defoliated-compiled.shp')

NdefolFire.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1342 entries, 0 to 1341
# Data columns (total 27 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OGF_ID      1342 non-null   int64
#  1   r_id        1342 non-null   object
#  2   raster_id   1342 non-null   object
#  3   Fire_ID     1342 non-null   object
#  4   FIRE_DISTU  1342 non-null   object
#  5   FIRE_TYPE_  1342 non-null   object
#  6   Fire_Year   1342 non-null   int64
#  7   FIRE_GENER  1342 non-null   object
#  8   FIRE_RESPO  1342 non-null   object
#  9   FIRE_START  1342 non-null   object
#  10  FIRE_OUT_D  1342 non-null   object
#  11  FIRE_FINAL  1342 non-null   int64
#  12  LOCATION_A  1342 non-null   object
#  13  BUSINESS_E  1159 non-null   object
#  14  GENERAL_CO  719 non-null    object
#  15  GEOMETRY_U  383 non-null    object
#  16  EFFECTIVE_  1342 non-null   object
#  17  SYSTEM_DAT  1342 non-null   object
#  18  OBJECTID    1342 non-null   int64
# ...
