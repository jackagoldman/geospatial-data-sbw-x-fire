# %% [markdown]
# This script explores the rbr data for defoliated and non-defolaited perimeters and joins the time since defoliation and number of years defoliated data to the defoliated rbr data
#
# In the non-defoliated data, the fire SIO44-1993 is removed beacause there is no data available for that fire from GEE.

# %%
import plotly.express as px
import pandas as pd
import statsmodels
import numpy as np
from pathlib import Path

# %%
dfrbr = pd.read_csv("/Users/jgoldman/Library/CloudStorage/OneDrive-UniversityofToronto/Data/fire-only-sbw-only-perimeters/cleaned/defol-fire-perims-rbr.csv")

# %%
dfrbr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321 entries, 0 to 320
# Data columns (total 35 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    321 non-null    int64
#  1   system:index  321 non-null    object
#  2   BUSINESS_E    318 non-null    object
#  3   EFFECTIVE_    321 non-null    object
#  4   FID_Dissol    321 non-null    int64
#  5   FID_ON_Fir    321 non-null    int64
#  6   FIRE_DISTU    321 non-null    object
#  7   FIRE_FINAL    321 non-null    int64
#  8   FIRE_GENER    321 non-null    object
#  9   FIRE_OUT_D    321 non-null    object
#  10  FIRE_RESPO    321 non-null    object
#  11  FIRE_START    321 non-null    object
#  12  FIRE_TYPE_    321 non-null    object
#  13  Fire_ID       321 non-null    object
#  14  Fire_Year     321 non-null    int64
#  15  GENERAL_CO    198 non-null    object
#  16  GEOMETRY_U    12 non-null     object
#  17  LOCATION_A    321 non-null    object
# ...

# %%
figScatExt = px.scatter(
    dfrbr, x='Fire_Year', y='rbrExtreme', 
    title='Extreme Burn Severity for each Fire Year', trendline="ols")

figScatExt.show()
# Out:
# <div>                            <div id="1a66441e-c9e9-4eed-9f05-9e0cf1d6d895" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a66441e-c9e9-4eed-9f05-9e0cf1d6d895")) {                    Plotly.newPlot(                        "1a66441e-c9e9-4eed-9f05-9e0cf1d6d895",                        [{"hovertemplate":"Fire_Year=%{x}\u003cbr\u003erbrExtreme=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[2011,2011,2011,2012,2012,2012,2016,1997,1997,1997,1997,1997,1997,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1999,1999,1999,1999,1999,1999,1999,1999,1999,1
# ...

# %%
figScatMed = px.scatter(
    dfrbr, x='Fire_Year', y='rbrMedian', 
    title='Median Burn Severity for each Fire Year', trendline="ols")

figScatMed.show()
# Out:
# <div>                            <div id="2644da1c-6ab7-4cbe-9a58-a36168d8125a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2644da1c-6ab7-4cbe-9a58-a36168d8125a")) {                    Plotly.newPlot(                        "2644da1c-6ab7-4cbe-9a58-a36168d8125a",                        [{"hovertemplate":"Fire_Year=%{x}\u003cbr\u003erbrMedian=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[2011,2011,2011,2012,2012,2012,2016,1997,1997,1997,1997,1997,1997,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1999,1999,1999,1999,1999,1999,1999,1999,1999,19
# ...

# %%
figBoxExt = px.box(dfrbr, x="Fire_Year", y="rbrExtreme")
figBoxExt.show()
# Out:
# <div>                            <div id="8b9a177f-8021-4a2f-816a-af842d94dc31" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8b9a177f-8021-4a2f-816a-af842d94dc31")) {                    Plotly.newPlot(                        "8b9a177f-8021-4a2f-816a-af842d94dc31",                        [{"alignmentgroup":"True","hovertemplate":"Fire_Year=%{x}\u003cbr\u003erbrExtreme=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":[2011,2011,2011,2012,2012,2012,2016,1997,1997,1997,1997,1997,1997,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1999,1999,1999,1999,1999
# ...

# %%
figBoxMed = px.box(dfrbr, x="Fire_Year", y="rbrMedian")
figBoxMed.show()
# Out:
# <div>                            <div id="ede76ecc-866b-4e05-88c1-5195ec012fb1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ede76ecc-866b-4e05-88c1-5195ec012fb1")) {                    Plotly.newPlot(                        "ede76ecc-866b-4e05-88c1-5195ec012fb1",                        [{"alignmentgroup":"True","hovertemplate":"Fire_Year=%{x}\u003cbr\u003erbrMedian=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":[2011,2011,2011,2012,2012,2012,2016,1997,1997,1997,1997,1997,1997,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1999,1999,1999,1999,1999,
# ...

# %%
dfsbw = pd.read_csv("/Users/jgoldman/Work/PhD/sbw-fire-interactions/nbr-recovery/data/clean/sbw-defol-data.csv")
dfsbw.head()
# Out:
#    Unnamed: 0       Fire_ID  defol  years_defol  tsd
# 0           1  PEM3_2001_11      0            0    0
# 1           2  PEM2_2000_35      0            0    0
# 2           3  KEM1_2000_36      0            0    0
# 3           4  PET1_2001_50      0            0    0
# 4           5  SAU8_2000_61      0            0    0

# %%
# left join df rbr to sbw_defol
dfDefol = dfrbr.merge(dfsbw, how ='inner', on='Fire_ID')
dfDefol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321 entries, 0 to 320
# Data columns (total 39 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0_x  321 non-null    int64
#  1   system:index  321 non-null    object
#  2   BUSINESS_E    318 non-null    object
#  3   EFFECTIVE_    321 non-null    object
#  4   FID_Dissol    321 non-null    int64
#  5   FID_ON_Fir    321 non-null    int64
#  6   FIRE_DISTU    321 non-null    object
#  7   FIRE_FINAL    321 non-null    int64
#  8   FIRE_GENER    321 non-null    object
#  9   FIRE_OUT_D    321 non-null    object
#  10  FIRE_RESPO    321 non-null    object
#  11  FIRE_START    321 non-null    object
#  12  FIRE_TYPE_    321 non-null    object
#  13  Fire_ID       321 non-null    object
#  14  Fire_Year     321 non-null    int64
#  15  GENERAL_CO    198 non-null    object
#  16  GEOMETRY_U    12 non-null     object
#  17  LOCATION_A    321 non-null    object
# ...

# %%
#write the data
outfolder = Path("/Users/jgoldman/Library/CloudStorage/OneDrive-UniversityofToronto/Data/fire-only-sbw-only-perimeters/cleaned")
dfDefol.to_csv(outfolder/ 'defoliated-perims-rbr-v2.csv')
